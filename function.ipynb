# %%
sum?
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
def greet():
    """greeting the programmer"""
    print("hello, welcome to python!")
    
print(greet())
# Out:
# hello, welcome to python!
# None

# %%
def greet():
    """greeting the programmer"""
    print("hello, welcome to python!")
    
greet()
# Out:
# hello, welcome to python!

# %%
greet?
# Out:
# Signature: greet()
# Docstring: greeting the programmer
# File:      c:\users\akash\appdata\local\temp\ipykernel_11924\2685879062.py
# Type:      function

# %%
#fuction calls:
def greet(name,dept):
    """returing a greeting message"""
    return F"HELLO, {name}!,Department: {dept}"

print(greet("Akash","DAS"))
# Out:
# HELLO, Akash!,Department: DAS

# %%
def add(a,b):
    return a+b
result = add(2,3)
print("Sum:", result)
# Out:
# Sum: 5

# %%
def multiply(a,b,c):
    return a*b*c
print(multiply(1,2,4))
# Out:
# 8

# %%
def calculate_area(length,width):
    """helps in calculating the area of a rectangle"""
    area = length*width
    return area

room_area= calculate_area(10,5)
print(f"The area of room is: {room_area} square meters!")

calculate_area?
# Out:
# The area of room is: 50 square meters!
# Signature: calculate_area(length, width)
# Docstring: helps in calculating the area of a rectangle
# File:      c:\users\akash\appdata\local\temp\ipykernel_11924\1043812200.py
# Type:      function

# %%
def greet_user(name="Guest"):
    print("Hello!,",name)

greet_user()
greet_user("Akash")
# Out:
# Hello!, Guest
# Hello!, Akash

# %%
def power(base,exponent=2):
    return base ** exponent
print(power(5,))
print(power(2,3))
# Out:
# 25
# 8

# %%
def sum(n):
    return n*n
sum(6)
# Out:
# 36

# %%
sum?
# Out:
# Signature: sum(n)
# Docstring: <no docstring>
# File:      c:\users\akash\appdata\local\temp\ipykernel_11924\3876347482.py
# Type:      function

# %%
max?
# Out:
# Docstring:
# max(iterable, *[, default=obj, key=func]) -> value
# max(arg1, arg2, *args, *[, key=func]) -> value
#
# With a single iterable argument, return its biggest item. The
# default keyword-only argument specifies an object to return if
# the provided iterable is empty.
# With two or more arguments, return the largest argument.
# Type:      builtin_function_or_method

# %%
def max(n):
    return n+n
max(6)
# Out:
# 12

# %%
max?
# Out:
# Signature: max(n)
# Docstring: <no docstring>
# File:      c:\users\akash\appdata\local\temp\ipykernel_11924\3637241570.py
# Type:      function

# %%
def circle_calculations(radius):
     """Calculates area and circumference of a circle"""
     import math
     area=math.pi*radius**2
     circumference=2*math.pi*radius
     return area,circumference

area,circ= circle_calculations(7)
print(f"Area: {area:.2f}") 
print(f"circumference:{circ:.2f}")
# Out:
# Area: 153.94
# circumference:43.98

# %%
def show_args(*args):
    print("args:",args)
show_args(1,2,3,4,5)
# Out:
# args: (1, 2, 3, 4, 5)

# %%
def show_kwargs(**kwargs):
    print("kwargs:",kwargs)
show_kwargs(name="akash",age=22)
# Out:
# kwargs: {'name': 'akash', 'age': 22}

# %%
def sum_numbers(*args):
    total=0
    for num in args:
        total+=num
    return total
print(sum_numbers(1,2,3))
# Out:
# 6

# %%
def create_person(**kwargs):
    person ={}
    for key, value in kwargs.items():
        person[key]=value
    return person
print(create_person(name="akash",age=22,city="kanyakumari"))
# Out:
# {'name': 'akash', 'age': 22, 'city': 'kanyakumari'}

# %%
#Recursive  functions

# %%
#factorial
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
        return n* factorial(n-1)
print(factorial(5))
# Out:
# 120

# %%
#fabonacci
def fibonacci(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fibonacci(n-1)+ fibonacci(n-2)
print(fibonacci(6))
# Out:
# 8

# %%
#Sum of a list
def recursive_sum(lst):
    if not lst:
        return 0
    else:
        return lst[0]+recursive_sum(lst[1:])
print(recursive_sum([1,2,3,4,5]))
# Out:
# 15

# %% [markdown]
# # Global and Local

# %%
counter = 0
def increment():
    global counter 
    counter+=1
    print("counter inside function:",counter)

increment()
counter
# Out:
# counter inside function: 1
# 1

# %%
print("counter outside fuction:",counter)
# Out:
# counter outside fuction: 1

# %%
def calculate_discount(price: float,discount_rate:float=0.10) -> float:
    if price <0:
        raise  ValueError("Price cannot be negative")
    if not(0<= discount_rate <=1):
        raise ValueError("Discount rate must be between 0 and 1")

    return price * (1- discount_rate)
final_price = calculate_discount(1200,0.25)
print(f"Final price after discount: ${final_price}")
# Out:
# Final price after discount: $900.0

# %%
#lambda function:

# %%
#regular function:
def square(x):
    return x**2
square(2)
# Out:
# 4

# %%
#lambda function for the regular function:
square_lambda= lambda x:x**2
square_lambda(3)
# Out:
# 9

# %%
multiply = lambda a,b:a*b
multiply(2,3)
# Out:
# 6

# %%
#using lambda inside built_in function:
numbers=[1,2,3,4,5]
squared=list(map(lambda x:x**2,numbers))
print(squared)
# Out:
# [1, 4, 9, 16, 25]

# %%
#Python Modules and Packages:

# %%
import mymodule as m
m.greet("akash")
# Out:
# 'Hello,akash!'

# %%
#import Statement:

# %%
import math
print("square root of 64:", math.sqrt(64))
# Out:
# square root of 64: 8.0

# %%
from math import pi,factorial,e
print("PI:",pi)
print("Expoential:",e)
print("factorial of 5:", factorial(5))
# Out:
# PI: 3.141592653589793
# Expoential: 2.718281828459045
# factorial of 5: 120

# %%
#importing every fuction from a module
from math import*
print(sin(0))
print(cos(0))
print(pow(2,3))
# Out:
# 0.0
# 1.0
# 8.0

# %%
import math
print("Ceil of 4.2:", math.ceil(4.2))
# Out:
# Ceil of 4.2: 5

# %%
print("Floor of 4.8:", math.floor(4.8))
print("power of 4.8:", math.pow(2,5))
print("cosine of 0:", math.cos(0))
# Out:
# Floor of 4.8: 4
# power of 4.8: 32.0
# cosine of 0: 1.0

# %%
#python package creation

# %%
#importing user defined packages:
import mypackage.module1 as m1
from mypackage import module2 as m2
print(m1.add(2,3))
print(m2.multiply(2,3,4))
# Out:
# 5
# 24
