# %%
file=open("sample.txt","w")
file.write("Hello World \n")
file.write("Python is a programmming language")
file.close()

# %%
file=open("sample.txt","r")
content=file.read()
print(content)
# Out:
# Hello World
# Python is a programmming language

# %%
file=open("sample.txt","a")
file.write("\nPython is user friendly")
file.close()

# %%
#Using with:

# %%
with open("sample.txt","r") as file:
    content =file.read()
    print(content)
# Out:
# Hello World
# Python is a programmming language
# Python is user friendly

# %%
with open("sample.txt","w") as file:
    file.write("\nPython is High-level language")

# %%
with open("sample.txt", "r+") as file:
    print(file.read())      # Read content

    file.write("\nNew Line Added")
# Out:
# Python is High-level language

# %%
#Exception handling in python:

# %%
#try...except Block:
try:
    num=int(input("Enter the number:"))
except ValueError:
    print("Invalid input! please enter a valid number.")
else:
    print("No error")
# Out:
# Enter the number: 10a
# Invalid input! please enter a valid number.

# %%
try:
    result=10/0
except ZeroDivisionError:
    print("Division by zero is not allowed.")
# Out:
# Division by zero is not allowed.

# %%
#Catching Specific Exception Types:
try:
    result = int("100a")
except Exception as e:
    print(f"An unexpected error occurred :{e}")
# Out:
# An unexpected error occurred :invalid literal for int() with base 10: '100a'

# %%
#using assert statement
age = -25
assert age > 0, "x must be positive"
assert age < 0, "x must be negative"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 3
#       1 #using assert statement
#       2 age = -25
# ----> 3 assert age > 0, "x must be positive"
#       4 assert age < 0, "x must be negative"
#
# AssertionError: x must be positive

# %%
#final statement:
try:
    file = open("sample.txt", "w")
    file.write("Hello")
#print(1 / 0) # Will raise ZeroDivisionError
except ZeroDivisionError:
    print("Cannot divide by zero.")
else:
    print("No Error")
finally:
    file.close()
    print("File closed.")
# Out:
# No Error
# File closed.
